# %% [markdown]
# <a href="https://colab.research.google.com/github/Downedw/Petrophysics/blob/main/CM3000%20Topic%201%20Worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = 14*5
q = math.sqrt(10)
print(p)
print(q)
# Out:
# 70
# 3.1622776601683795

# %%
r = 8+q
s = q**2
t = p*q
print(r, s, t)
# Out:
# 11.16227766016838 10.000000000000002 221.35943621178657

# %%
x =  [0,1,2,3,4,5]
y = [0,1,4,9,16,25]

import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
plt.plot(x,y,color = 'red')

# %%
plt.scatter(x,y, color = 'r')

# %%
import pandas as pd
df1 = pd.DataFrame({'x': x,
                    'y': y})
df1.plot.line('x','y', color = 'r')
# Out:
# <Axes: xlabel='x'>

# %%
df1.plot.scatter('x','y', color = 'g')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
year = ["2016", "2017", "2018", "2019"]
sales = [350, 270, 40, 600]
df2 = pd.DataFrame({'sales': sales},
                   index = year)
df2.plot.pie(y='sales', figsize = (5,5))
# Out:
# <Axes: ylabel='sales'>

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
import numpy as np
#use data from above
#plot
fig,ax = plt.subplots()

ax.bar(year,sales, width = 1, edgecolor = "white", linewidth = 2)



plt.show()
